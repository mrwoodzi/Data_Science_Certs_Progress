# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Define the path to the CSV file
#Laptop
csv_file_path = r"C:\Users\mrwoo\OneDrive\Desktop\SA_Interview\all_311_transformed.csv"

#Server
#csv_file_path = "/home/mrwoo/Documents/all_331_transformed.csv"

# Reset display options to default
pd.reset_option('display.max_columns')
pd.reset_option('display.max_rows')
pd.reset_option('display.max_colwidth')

# Read the CSV file into a pandas DataFrame
df = pd.read_csv(csv_file_path)

# Display the DataFrame
df
# Out:
#                          Category      CASEID OPENEDDATETIME    SLA_Date  \
# 0       Traffic Signals and Signs  1014001765      11/3/2017   9/22/2021
# 1            Solid Waste Services  1014303843       3/7/2018   3/16/2018
# 2       Traffic Signals and Signs  1014504120      5/11/2018  10/31/2018
# 3       Traffic Signals and Signs  1014549690      5/27/2018  11/15/2018
# 4            Solid Waste Services  1014569491       6/3/2018   6/11/2018
# ...                           ...         ...            ...         ...
# 606056                    Animals  1019442050       3/1/2024   3/11/2024
# 606057                    Animals  1019442051       3/1/2024   3/11/2024
# 606058                    Animals  1019442052       3/1/2024    3/2/2024
# 606059                    Animals  1019442053       3/1/2024    3/2/2024
# 606060       Property Maintenance  1019442054       3/1/2024    5/8/2024
#
#        CLOSEDDATETIME Late (Yes/No)                    Dept  \
# 0          2023-03-16           YES            Public Works
# 1          2023-03-08           YES  Solid Waste Management
# 2          2023-03-16           YES            Public Works
# 3          2023-03-16           YES            Public Works
# 4                 NaN           YES  Solid Waste Management
# ...               ...           ...                     ...
# 606056            NaN            NO    Animal Care Services
# 606057            NaN            NO    Animal Care Services
# 606058     2024-03-01            NO    Animal Care Services
# 606059            NaN            NO    Animal Care Services
# 606060            NaN            NO    Development Services
#
#                         REASONNAME                                TYPENAME  \
# 0                          Signals  Signal Timing Modification By Engineer
# 1                 Waste Collection                 Additional Cart Request
# 2       Traffic Engineering Design              Traffic Signal New Request
# 3       Traffic Engineering Design              Traffic Signal New Request
# 4                 Waste Collection                            Damaged Cart
# ...                            ...                                     ...
# 606056            Field Operations                Animals(Public Nuisance)
# 606057            Field Operations                Animals(Public Nuisance)
# 606058            Field Operations                             Third Shift
# 606059            Field Operations                             Third Shift
# 606060            Code Enforcement                    Overgrown Yard/Trash
#
#        CaseStatus              SourceID  \
# 0          Closed      Constituent Call
# 1          Closed      Constituent Call
# 2          Closed      Constituent Call
# 3          Closed      Constituent Call
# 4            Open      Constituent Call
# ...           ...                   ...
# 606056       Open      Constituent Call
# 606057       Open      Constituent Call
# 606058     Closed      Constituent Call
# 606059       Open      Constituent Call
# 606060       Open  Code Proactive Calls
#
#                                     OBJECTDESC  Council District  \
# 0                    PATRON and POTEET JDTN FY                 4
# 1        1819  POPLAR ST W, San Antonio, 78207                 1
# 2                HILDEBRAND E and NEW BRNFLS N                 2
# 3               PERRIN BEITEL and SUNSHADOW ST                10
# 4            220  BROADWAY, San Antonio, 78205                 1
# ...                                        ...               ...
# 606056   319 AMBERDALE OAK, SAN ANTONIO, 78249                 8
# 606057        11631 HIDDEN TERRACE, UBC, 78245                 0
# 606058         55 CONSUELO, SAN ANTONIO, 78228                 5
# 606059    7950 MEADOW STAR, SAN ANTONIO, 78227                 6
# 606060         1102 ADA ST, SAN ANTONIO, 78223                 3
#
#        Report Starting Date Report Ending Date   LATITUDE  LONGITUDE
# 0                  3/2/2023           3/2/2024  29.338427 -98.550563
# 1                  3/2/2023           3/2/2024  29.440466 -98.519462
# 2                  3/2/2023           3/2/2024  29.465814 -98.460859
# 3                  3/2/2023           3/2/2024  29.523482 -98.410947
# 4                  3/2/2023           3/2/2024  29.428094 -98.487158
# ...                     ...                ...        ...        ...
# 606056             3/2/2023           3/2/2024  29.575311 -98.629121
# 606057             3/2/2023           3/2/2024  29.409398 -98.723522
# 606058             3/2/2023           3/2/2024  29.441727 -98.582815
# 606059             3/2/2023           3/2/2024  29.420643 -98.644207
# 606060             3/2/2023           3/2/2024  29.380866 -98.456539
#
# [606061 rows x 17 columns]

# %%
# Convert 'Council District' to 'District' and change its type to string
df.rename(columns={'Council District': 'District'}, inplace=True)
df['District'] = df['District'].astype(str)

# Convert date columns to date objects
date_columns = ['OPENEDDATETIME', 'SLA_Date', 'CLOSEDDATETIME', 'Report Starting Date', 'Report Ending Date']
df[date_columns] = df[date_columns].apply(pd.to_datetime)

# %%
df.drop(columns='OBJECTDESC', inplace=True)

# %%
column_names = {'REASONNAME' : 'Reason', 'TYPENAME' : 'Type', 'CASEID' : 'Case'}
df.rename(columns=column_names, inplace=True)

# %%
df.columns
# Out:
# Index(['Category', 'Case', 'OPENEDDATETIME', 'SLA_Date', 'CLOSEDDATETIME',
#        'Late (Yes/No)', 'Dept', 'Reason', 'Type', 'CaseStatus', 'SourceID',
#        'District', 'Report Starting Date', 'Report Ending Date', 'LATITUDE',
#        'LONGITUDE'],
#       dtype='object')

# %%
columns_change = { 'OPENEDDATETIME' : 'Opened', 'CLOSEDDATETIME' : 'Closed', 'SLA_Date' : 'SLA'}
df.rename(columns=columns_change, inplace=True)

# %%
#Converting District column to numeric
df['District'] = pd.to_numeric(df['District'], errors='coerce')

# %%
# Out:
# dtype('int64')

# %%
# Define a mapping dictionary for numerical values to words
number_to_word = {
    0: 'Zero',
    1: 'One',
    2: 'Two',
    3: 'Three',
    4: 'Four',
    5: 'Five',
    6: 'Six',
    7: 'Seven',
    8: 'Eight',
    9: 'Nine',
    10: 'Ten'
}

# Use the map() function to replace numerical values with words
df['District'] = df['District'].map(number_to_word)

# %%
df.to_csv(r"C:\Users\mrwoo\OneDrive\Desktop\SA_Interview\311.csv", index=False)
