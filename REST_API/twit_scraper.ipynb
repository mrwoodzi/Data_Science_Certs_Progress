# %%
import pandas as pd
from tqdm.notebook import tqdm
import snscrape.modules.twitter as sntwitter

# %%
scraper = sntwitter.TwitterSearchScraper("#louderwithcrowder")

# %%
for tweet in scraper.get_items():
    break
tweet
# Out:
# Tweet(url='https://twitter.com/EffortlessTruth/status/1621574325315715080', date=datetime.datetime(2023, 2, 3, 18, 20, 21, tzinfo=datetime.timezone.utc), rawContent='Really…\n\n#louderwithcrowder #fightlikehell #woke #bigcon https://t.co/5OnCZHMMwX', renderedContent='Really…\n\n#louderwithcrowder #fightlikehell #woke #bigcon https://t.co/5OnCZHMMwX', id=1621574325315715080, user=User(username='EffortlessTruth', id=1541568442288971777, displayname='EffortlessTruth', rawDescription='Exploring the Simple Truth', renderedDescription='Exploring the Simple Truth', descriptionLinks=None, verified=False, created=datetime.datetime(2022, 6, 27, 23, 45, 42, tzinfo=datetime.timezone.utc), followersCount=15, friendsCount=130, statusesCount=199, favouritesCount=256, listedCount=0, mediaCount=6, location='', protected=False, link=None, profileImageUrl='https://pbs.twimg.com/profile_images/1543039695784919042/FZJ1j0no_normal.jpg', profileBannerUrl='https://pbs.twimg.com/profile_banners/1541568442288
# ...

# %%
data = [
    tweet.date, 
    tweet.id, 
    tweet.rawContent, 
    tweet.user.username, 
    tweet.likeCount, 
    tweet.retweetCount,
]
data
# Out:
# [datetime.datetime(2023, 2, 3, 18, 20, 21, tzinfo=datetime.timezone.utc),
#  1621574325315715080,
#  'Really…\n\n#louderwithcrowder #fightlikehell #woke #bigcon https://t.co/5OnCZHMMwX',
#  'EffortlessTruth',
#  0,
#  0]

# %%
scraper = sntwitter.TwitterSearchScraper("#louderwithcrowder")

tweets = []

for i, tweet in enumerate(scraper.get_items()):
    data = [
    tweet.date, 
    tweet.id, 
    tweet.rawContent, 
    tweet.user.username, 
    tweet.likeCount, 
    tweet.retweetCount,
]
    tweets.append(data)
    if i > 50:
        break

# %%
tweet
# Out:
# Tweet(url='https://twitter.com/LibrlConundrums/status/1617722674180165632', date=datetime.datetime(2023, 1, 24, 3, 15, 16, tzinfo=datetime.timezone.utc), rawContent="Welp, that was disappointing to say the least. Crowder still thinks he's right, and is absolutely not. As a LwC fan, atm I probably won't be subscribing to anything new. #louderwithcrowder #mugclubforever #crowdervsDW #timcast", renderedContent="Welp, that was disappointing to say the least. Crowder still thinks he's right, and is absolutely not. As a LwC fan, atm I probably won't be subscribing to anything new. #louderwithcrowder #mugclubforever #crowdervsDW #timcast", id=1617722674180165632, user=User(username='LibrlConundrums', id=507551012, displayname='LiberalConundrums', rawDescription='Exploring and sharing some of the many confusing liberal viewpoints.', renderedDescription='Exploring and sharing some of the many confusing liberal viewpoints.', descriptionLinks=None, verified=False, created=datetime.datetime(2012
# ...

# %%
pd.DataFrame(tweets, columns=["date", "id", "content", "username", "like_count", "retweet_count"])
# Out:
#                         date                   id  \
# 0  2023-02-03 18:20:21+00:00  1621574325315715080
# 1  2023-02-03 15:46:44+00:00  1621535666948526086
# 2  2023-02-03 07:54:13+00:00  1621416753220780035
# 3  2023-02-03 04:19:45+00:00  1621362780849717253
# 4  2023-02-03 02:40:06+00:00  1621337706734182400
# 5  2023-02-02 12:57:26+00:00  1621130672466444290
# 6  2023-02-01 05:20:10+00:00  1620653210104131584
# 7  2023-02-01 05:16:45+00:00  1620652349663629315
# 8  2023-01-31 01:00:06+00:00  1620225375996645376
# 9  2023-01-30 20:00:01+00:00  1620149855493431324
# 10 2023-01-30 20:00:01+00:00  1620149854998503444
# 11 2023-01-30 20:00:00+00:00  1620149854012842018
# 12 2023-01-30 15:07:53+00:00  1620076340342042624
# 13 2023-01-28 19:54:30+00:00  1619423693775736832
# 14 2023-01-28 15:52:29+00:00  1619362789084254208
# 15 2023-01-28 14:35:09+00:00  1619343326477713409
# 16 2023-01-28 14:33:14+00:00  1619342841930727424
# 17 2023-01-28 14:18:15+00:00  1619339074409730049
# ...

# %% [markdown]
# # Adding a Progress Bar

# %%
scraper = sntwitter.TwitterSearchScraper("@scrowder")

tweets = []
n_tweets = 1000
for i, tweet in tqdm(enumerate(scraper.get_items()), total=n_tweets):
    data = [
    tweet.date, 
    tweet.id, 
    tweet.rawContent, 
    tweet.user.username, 
    tweet.likeCount, 
    tweet.retweetCount,
]
    tweets.append(data)
    if i > n_tweets:
        break
scrowder = pd.DataFrame(tweets, columns=["date", "id", "content", "username", "like_count", "retweet_count"])
# Out:
#   0%|          | 0/1000 [00:00<?, ?it/s]

# %% [markdown]
# # Setting the display Options for All of the text

# %%
pd.options.display.max_rows
pd.set_option('display.max_colwidth', None)
scrowder.head(1)
# Out:
#                        date                   id  \
# 0 2023-02-03 20:55:59+00:00  1621613493395791873
#
#                                                                                               content  \
# 0  @scrowder Kentucky requires one person to authorize a recording. Be aware. https://t.co/FeuzgckZJg
#
#        username  like_count  retweet_count
# 0  GracenBeaumn           0              0

# %%
all_likes = scrowder.loc[(scrowder['like_count'] == 1)]
all_likes.head(3)
# Out:
#                         date                   id  \
# 1  2023-02-03 20:55:31+00:00  1621613373833023488
# 10 2023-02-03 20:15:01+00:00  1621603184119521286
# 11 2023-02-03 20:06:22+00:00  1621601004482338821
#
#                                                                                                                                                                                                        content  \
# 1                                          @UnWokablePod @RMConservative @ConceptualJames @SovMichael @VivekGRamaswamy @jordanbpeterson @coddlethis42 @scrowder @LWCnewswire @theblaze https://t.co/qlawyh59mb
# 10                                        #WhatILearnedToday  \n@RealBradStaggs\n@RealRonPhillips\n@SCrowder\n\n*Brad!  The politically correct and socially sound term is “Mentally Challenged” - you retard!
# ...

# %%
likes_and_retweet = scrowder.loc[(scrowder['like_count'] == 1) & (scrowder['retweet_count'] == 1)]
likes_and_retweet.head(7)
# Out:
#                          date                   id  \
# 49  2023-02-03 17:06:07+00:00  1621555645567700993
# 84  2023-02-03 16:07:32+00:00  1621540901414658049
# 86  2023-02-03 16:06:04+00:00  1621540532458606593
# 270 2023-02-03 01:03:27+00:00  1621313383411728385
# 344 2023-02-02 18:18:53+00:00  1621211571316789254
# 596 2023-02-02 01:40:47+00:00  1620960387406471169
# 912 2023-02-01 10:51:14+00:00  1620736525406453761
#
#                                                                                                                                                                                                                                                                                                                                                                 content  \
# ...

# %%
like_count = scrowder['like_count']
import numpy as np 
counts = np.count_nonzero(like_count==1)
counts
#gives me number of times @sccrowder tweet was liked
# Out:
# 184

# %%
#lets figure out what those tweets said.

# %%
# Was it positive or negative

# %%
retweet_count = scrowder['retweet_count']
re_count = np.count_nonzero(retweet_count==1)
re_count
# Out:
# 27
